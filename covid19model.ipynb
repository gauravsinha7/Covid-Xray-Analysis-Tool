# %%
import os
import cv2
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

# %%
ROOT_DIR = os.getcwd()
dataset = os.path.join(ROOT_DIR, "dataset")

# %%
INIT_LR = 1e-3
EPOCHS = 25
BS = 8

# %%
print("[INFO] loading images...")
#imagePaths = 
data = []
normal = os.path.join(dataset, 'normal')

for imgName in os.listdir(normal):
    imagePath = os.path.join(normal, imgName)
    img = cv2.imread(imagePath)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))
    data.append(img)

covid = os.path.join(dataset, 'covid')

for imgName in os.listdir(covid):
    imagePath = os.path.join(covid, imgName)
    img = cv2.imread(imagePath)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))
    data.append(img)
    
print('Number of images :', len(data))
labels = ['normal' for name in os.listdir(os.path.join(dataset, 'normal'))] + ['covid' for name in os.listdir(os.path.join(dataset, 'covid'))]
print("labels...")
print(labels)
# Out:
# [INFO] loading images...
# Number of images : 50
# labels...
# ['normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid', 'covid']

# %%
data = np.array(data) / 255.0
labels = np.array(labels)

# %%
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# %%
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.20, stratify=labels, random_state=42)

# %%
trainAug = ImageDataGenerator(
            rotation_range=15,
            fill_mode="nearest")

# %%
baseModel = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# %%
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(4, 4))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(64, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# %%
model = Model(inputs=baseModel.input, outputs=headModel)

# %%
for layer in baseModel.layers:
    layer.trainable = False

# %%
print("[INFO] compiling model...")
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])
# Out:
# [INFO] compiling model...

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                32832
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 14,747,650
# Trainable params: 32,962
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
print("[INFO] training head...")
H = model.fit_generator(
        trainAug.flow(trainX, trainY, batch_size=BS),
        steps_per_epoch=len(trainX) // BS,
        validation_data=(testX, testY),
        validation_steps=len(testX) // BS, epochs=25) #, initial_epoch=30)
        #, initial_epoch=25)
        #epochs=EPOCHS)
# Out:
# [INFO] training head...
# WARNING:tensorflow:From <ipython-input-16-9b03a2d41ea6>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 5 steps, validate on 10 samples
# Epoch 1/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.9415 - accuracy: 0.4750 - val_loss: 0.5358 - val_accuracy: 0.6250
# Epoch 2/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.8049 - accuracy: 0.3750 - val_loss: 0.5141 - val_accuracy: 0.7500
# Epoch 3/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.7469 - accuracy: 0.5250 - val_loss: 0.4997 - val_accuracy: 0.7500
# Epoch 4/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.6271 - accuracy: 0.7000 - val_loss: 0.4902 - val_accuracy: 0.7500
# Epoch 5/25
# 5/5 [==============================] - 14s 3s/step - loss: 0.7160 - accuracy: 0.6250 - val_loss: 0.4725 - val_accuracy: 0.7500
# Epoch 6/25
# 5/5 [==============================] - 26s 5s/step - loss: 0.5911 - accuracy: 0.6500 - val_loss: 0.4473 - val_accuracy: 1.0000
# Epoch 7/25
# 5/5 [==============================] - 20s 4s/step - loss: 0.6159 - accuracy: 0.6750 - val_loss: 0.4308 - val_accuracy: 1.0000
# Epoch 8/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.5905 - accuracy: 0.6500 - val_loss: 0.4135 - val_accuracy: 1.0000
# Epoch 9/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.5802 - accuracy: 0.7000 - val_loss: 0.3999 - val_accuracy: 1.0000
# Epoch 10/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.5764 - accuracy: 0.6500 - val_loss: 0.3843 - val_accuracy: 1.0000
# Epoch 11/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.5396 - accuracy: 0.7000 - val_loss: 0.3663 - val_accuracy: 1.0000
# Epoch 12/25
# 5/5 [==============================] - 14s 3s/step - loss: 0.5398 - accuracy: 0.7250 - val_loss: 0.3582 - val_accuracy: 1.0000
# Epoch 13/25
# 5/5 [==============================] - 14s 3s/step - loss: 0.4588 - accuracy: 0.8750 - val_loss: 0.3444 - val_accuracy: 1.0000
# Epoch 14/25
# 5/5 [==============================] - 15s 3s/step - loss: 0.4307 - accuracy: 0.8750 - val_loss: 0.3325 - val_accuracy: 1.0000
# Epoch 15/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.4653 - accuracy: 0.8000 - val_loss: 0.3127 - val_accuracy: 1.0000
# Epoch 16/25
# 5/5 [==============================] - 15s 3s/step - loss: 0.4114 - accuracy: 0.8500 - val_loss: 0.2941 - val_accuracy: 1.0000
# Epoch 17/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.4634 - accuracy: 0.7500 - val_loss: 0.2913 - val_accuracy: 1.0000
# Epoch 18/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.4403 - accuracy: 0.8750 - val_loss: 0.2806 - val_accuracy: 1.0000
# Epoch 19/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.4227 - accuracy: 0.8500 - val_loss: 0.2664 - val_accuracy: 1.0000
# Epoch 20/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.4619 - accuracy: 0.7750 - val_loss: 0.2507 - val_accuracy: 1.0000
# Epoch 21/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.4085 - accuracy: 0.8750 - val_loss: 0.2371 - val_accuracy: 1.0000
# Epoch 22/25
# 5/5 [==============================] - 14s 3s/step - loss: 0.3053 - accuracy: 0.9750 - val_loss: 0.2262 - val_accuracy: 1.0000
# Epoch 23/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.3498 - accuracy: 0.8750 - val_loss: 0.2127 - val_accuracy: 1.0000
# Epoch 24/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.3254 - accuracy: 0.9000 - val_loss: 0.2057 - val_accuracy: 1.0000
# Epoch 25/25
# 5/5 [==============================] - 13s 3s/step - loss: 0.2660 - accuracy: 0.9250 - val_loss: 0.1903 - val_accuracy: 1.0000

# %%
print("[INFO] saving COVID-19 detector model...")
model.save('covid19.model', save_format="h5")
# Out:
# [INFO] saving COVID-19 detector model...

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on COVID-19 Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")

# %%
model_json = model.to_json()
open('architecture.json', 'w').write(model_json)
model.save_weights('weights.h5', overwrite=True)

# %%
from sklearn.externals import joblib
joblib.dump(H.history, 'history.pkl')
# Out:
# /Users/prateekgupta/opt/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# ['history.pkl']
